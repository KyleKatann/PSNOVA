# %%
from pandas import*
from glob import*

def printtag(line,tmp):
    tag="        <tr>"
    if not line[-1]:
        line[-1]="-"

    if "★" in line[1]:
        line[1]=line[1].split("★")[1]
    for item in zip(*tmp):
        tag+='<th>'+str(item[0])
        for name in item[1:]:
            if name:
                tag+='<br>'+name
        tag+='</th>'
    tag+="</tr>"

    if tmp:
        print(tag)

for name in sorted(glob("./excel/*.xlsx")):
    df=read_excel(name,header=None).fillna("").as_matrix()
    
    print('    <table border="1" style="border-collapse: collapse">')
    
    tag="        <tr>"
    for h in df[0]:
        tag+='<th bgcolor="#87cefa">'+h+'</th>'
    tag+="</tr>"
    print(tag)
    
    tmp=[]                
    
    for line in df[1:]:
        if line[0]:
            printtag(line,tmp)
            tmp=[]
            tmp.append(list(line))
        else:
            tmp.append(list(line))
        
    printtag(line,tmp)
    
    print("    </table>")
# Out:
#     <table border="1" style="border-collapse: collapse">
#         <tr><th bgcolor="#87cefa">名称</th><th bgcolor="#87cefa">内容</th><th bgcolor="#87cefa">入手方法</th><th bgcolor="#87cefa">種類</th></tr>
#         <tr><th>ファンタシースター ノヴァ マスター</th><th>"今ここに、新たな英雄の名が刻まれた。そして伝説へ。"</th><th>全てのトロフィーを獲得する</th><th>プラチナ</th></tr>
#         <tr><th>日記はじめました</th><th>"これから毎日日記をつけていくことにしたよ。勝手に見ちゃ駄目なんだからね、相棒！"</th><th>ストーリークエスト</th><th>ブロンズ</th></tr>
#         <tr><th>いないというか……いるというか……</th><th>"ユノにも好きな人がいるみたい。どんな人なんだろう？　まぁ、セイルじゃないってことはわかったけどね！"</th><th>ストーリークエスト</th><th>ブロンズ</th></tr>
#         <tr><th>ギガンテスキャプチャー</th><th>"はじめてギガンテスを捕獲！ これでパイルの使い方もばっちり。ギガンテスとも仲良し。"</th><th>ストーリークエスト　初ギガンテス捕獲時</th><th>ブロンズ</th></tr>
#         <tr><th>交錯する思惑</th><th>"脱出を優先するフィルディアと探査の続行を主張するレイヴァンが対立する。グラン・ドライブ完成まであとわずか……。"</th><th>ストーリークエスト</th><th>ブロンズ</th></tr>
#         <tr><th>喪失、そして惑星との新たな戦いの始まり</th><th>"マグナス艦長、フィルディア艦長の意思を引き継いでいく。新たな艦長として仲間達を無事生きてこの惑星から脱出させることが使命だ。"</th><th>ストーリークエスト グランドアクト2開始時</th><th>ブロンズ</th></tr>
#         <tr><th>滅びの歴史</th><th>"宝石に記された記録を調べれば、この惑星の歴史が分かる筈。悲しき過去に向き合わなくてはならない。"</th><th>ストーリークエスト</th><th>ブロンズ</th></tr>
#         <tr><th>大型パイルラストワン！</th><th>"大型パイルは残す所１本。立ちはだかる彼の目的とは一体？彼は一体どうしてしまったと言うのだろうか？"</th><th>ストーリークエスト</th><th>ブロンズ</th></tr>
#         <tr><th>ひとつの物語の幕引き……そして……</th><th>"長い時を経て、古代の約束は果たされた。あたし達が出会ったこの惑星の物語は、今幕を閉じる。"</th><th>ストーリークエスト</th><th>ゴールド</th></tr>
#         <tr><th>復興への一歩</th><th>"さぁ、街づくりの第一歩だよ！ これからあたし達だけの街を作っていこうね！ 相棒はどんな街にしてみたい？"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>探検発見みんなの街</th><th>"だいぶ発展してきたね！ これからあたしたち色に染め上げた街を作っちゃおう！"</th><th>全施設をレベル4にして配置する。なお、レベル5の施設が1つでもあると判定されないため、撤去が必要。レベル4の施設だけを配置する必要がある</th><th>シルバー</th></tr>
#         <tr><th>業物誕生</th><th>7の武器を作成！ これさえあれば怖いもの無し。貫けぬものない仲間達の矛となれ。"</th><th>★7の武器を作成(武器種は問わない) 8以上のを作成しても判定されない</th><th>-</th></tr>
#         <tr><th>大業物誕生</th><th>10の武器を作成！ この得物の前に敵うものなし。目の前に立ちふさがる全てを……斬る！"</th><th>★10の武器を作成(武器種は問わない) 11以上のを作成しても判定されない</th><th>シルバー</th></tr>
#         <tr><th>鉄壁の盾</th><th>7の防具を作成！ これさえあれば大丈夫。この防具で自分だけじゃなく仲間達も守ってみせる！"</th><th>★7の防具を作成 8以上のを作成しても判定されない</th><th>ブロンズ</th></tr>
#         <tr><th>最強の盾</th><th>10の防具を作成！ 全ての悪災をふり払い、仲間達を守り通す、最強の盾となれ。"</th><th>★10の武器を作成 11以上のを作成しても判定されない</th><th>シルバー</th></tr>
#         <tr><th>自由自在</th><th>7のアタッチパーツを作成！これで自分の武器を自由自在に彩ろう。戦場で目立つこと間違い無し。"</th><th>★7のアタッチパーツを作成 8以上のを作成しても判定されない</th><th>ブロンズ</th></tr>
#         <tr><th>変幻自在</th><th>10のアタッチパーツを作成！これで自分の武器を変幻自在に彩ろう。武器をふるう度に羨望の眼差しを受けること間違い無し。"</th><th>★10のアタッチパーツを作成 11以上のを作成しても判定されない</th><th>シルバー</th></tr>
#         <tr><th>これぞ俺流</th><th>"4個のアタッチパーツを同時装着！だってカッコイイんだもん！たくさんつけて、己の道を突き進め！"</th><th>ひとつの武器にアタッチパーツを4つ装着する</th><th>ブロンズ</th></tr>
#         <tr><th>ずっと相棒と一緒</th><th>"役に立たなくても、わがままでも、ずっとそばにいたいの。こんなあたしだけど許してね？これからもよろしく、相棒！"</th><th>ルティナの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>不倒のセイル</th><th>"あの時オレを救ってくれた金髪とピンク頭の二人組の女たちは一体……？今でもアークスとして活躍しているなら一言礼が言いたいぜ。"</th><th>セイルの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>チーズケーキの味</th><th>"今まで私は、姉と疎遠になっていたんです。無事にこの惑星から脱出できたら、その姉に会いに行くつもりです。"</th><th>イズナの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>遥かな時と銀河を超えて出会った二人</th><th>"運命という言葉は信じない。そんな安い言葉では言い知れないからだ。ただ彼女と出会えた奇跡に感謝し、この感情を分かち合いたい。"</th><th>レイヴァン＆ユノの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>オペレーターとして</th><th>"今まで一人で抱えていた気持ちを、あなたに聞いてもらえて良かった。これからもオペレーターとして、私はあなたを支え続けるわ。"</th><th>キサラの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>体調管理は大事です</th><th>"素行の悪い人はお仕置きです。極太お注射であなたの急所を狙い打ち！ですよ？"</th><th>リーティアの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>職人の心意気</th><th>"お前達が結果を出したのだから、ここからは俺の領分だな。言葉で感謝を伝えるのは容易いが、もっと確かな手応えを与えよう。"</th><th>カリストの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>オルクスパパと家族の絆</th><th>"やっとカミさんからの便りを読むことができた。また家族と会いたいと思えるようになったのは、お前達のお陰だ。感謝してるぜ。"</th><th>オルクスの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>当たり前の料理</th><th>"みなさん慌てず召し上がれ。ところであの話はどこまで本当か？ですって～？ それは……内緒なのですよ！"</th><th>ヒュペリオンの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>オレは武器職人王になる！</th><th>"武器を作る者と扱う者、両者が互いに切磋することで高みへと近付いていくんだな。オレとお前なら、新しい伝説も生み出せる筈だ！"</th><th>ヨミの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>恋人は仕事……？</th><th>"私は……あの人の喜んでいる顔を見たくて、仕事をしていたのでしょうか？ んー、んー、解析不能です。"</th><th>シャロンの友好度</th><th>ブロンズ</th></tr>
#         <tr><th>英雄の意思</th><th>"お前らならやれると信じてるぞ。見ててやるから、好き放題暴れてみせろ！ いつかエスコートしてくれるのを待ってるからな！"</th><th>クリア後のフィルディアの好感度を最大にして<br>全てのプロミスオーダーをクリアしイベントを見る</th><th>ブロンズ</th></tr>
#         <tr><th>師範代</th><th>"レベル50を達成！ かなり熟練した戦士。そろそろ弟子でもとったらどうですか？"</th><th>いずれかのクラスレベルが50に到達する</th><th>ブロンズ</th></tr>
#         <tr><th>師範</th><th>"レベル100を達成！ アークス最強の戦士に仲間入り。これであなたもモッテモテ！"</th><th>いずれかのクラスレベルが100に到達する</th><th>シルバー</th></tr>
#         <tr><th>はじめての解凍</th><th>"はじめてクルーを解凍！ 記念すべき仲間第一号はどんな子かな？ これから一緒にこの惑星を探索していこう！"</th><th></th><th>ブロンズ</th></tr>
#         <tr><th>クルー増加中</th><th>"様々なクルーを解凍！ そろそろお気に入りの子は出てきたかな？　自分のお気に入りの子だけを揃えて最強の部隊を作ろう！"</th><th></th><th>ブロンズ</th></tr>
#         <tr><th>クルーいっぱい</th><th>"多くのクルーを解凍！ あんな子もこんな子も命令し放題。適材適所で自分だけの帝国を作ろう！"</th><th>クルー300人突破<br>(特典クルー除く？)</th><th>シルバー</th></tr>
#         <tr><th>英雄の勲章</th><th>"ダーカーを1111体撃破！ これであの人に少しは近づけた筈。もらった勲章は大切にしよう。"</th><th>ダーカーの撃破数が1111に到達する 判定はひとつのセーブファイルごと</th><th>ブロンズ</th></tr>
#         <tr><th>英雄王の勲章</th><th>"エネミーを11111体撃破！ 伝説に残る偉業を達成。これであの人と肩を並べる英雄になれた筈。その勲章に恥じぬアークスとなろう。"</th><th></th><th>シルバー</th></tr>
#         <tr><th>ギガンテススレイヤー</th><th>"ギガンテスを111体撃破！ その骸の先に何があるのか！？ ギガンテス殺しの二つ名を得た君が見据えるその先にあるモノとは……<br>※シミュレーター、訓練のギガンテスは対象外"</th><th></th><th>シルバー</th></tr>
#         <tr><th>アルテイオスハンター</th><th>"アルテイオスに勝利！<br>でっかい甘えん坊竜おしおき！ もう大砲だってへっちゃら！"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>ヴィヴリュードハンター</th><th>"ヴィヴリュードに勝利！<br>でっかいエビをおしおき！ 今夜はギガ海鮮丼・特盛り！"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>グラヴディオンハンター</th><th>"グラヴディオンに勝利！<br>でっかいお馬さんをおしおき！ これでチェーンソーの騒音も解消！"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>デェフキュオネハンター</th><th>"デェフキュオネに勝利！<br>でっかいうねうねをおしおき！ これで大火事の心配もナッシング！"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>リベルゲンテハンター</th><th>"リベルゲンテに勝利！<br>虫のような列車のようなギガンテスから何とか拠点と仲間達を守り切ることに成功！"</th><th>-</th><th>ブロンズ</th></tr>
#         <tr><th>レイヴガイストハンター</th><th>"レイヴガイストに勝利！<br>惑星ノヴァ最強の守護神を超え、英雄達の新たな最強伝説が始まる。"</th><th>-</th><th>シルバー</th></tr>
#         <tr><th>ソードDEデート</th><th>"エスコートの約束を果たしてくれてありがとな。<br>背中を預けられる安心感ってヤツを思い出したよ。またつきあってくれるよな相棒！"</th><th>「難:★ラスト・デート」のクリアイベントを見る<br>このクエストは全メインクルーの友好度関連トロフィー入手後<br>ブリッジにてフィルディアに話しかけることで追加される</th><th>ゴールド</th></tr>
#         <tr><th>湯けむりの向こう側へ</th><th>"覗かなかった者は一流のアークス。最後まで覗いた物もまた、一流のアークス。<br>そんな気がしてならない！"</th><th>拠点施設：スパ(ミニスパでも可)を設置し<br>ラボから退出する際に自動発生するイベントを見る</th><th>-</th></tr>
#     </table>
# C:\Users\kyle\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
